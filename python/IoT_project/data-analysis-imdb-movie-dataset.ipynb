# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('imdb_movies.csv')

# %% [markdown]
# # 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#                           Names         Year  Rating  \
# 0                     Creed III   03/02/2023      73
# 1      Avatar: The Way of Water  12/15/2022       78
# 2   The Super Mario Bros. Movie   04/05/2023      76
# 3                       Mummies   01/05/2023      70
# 4                     Supercell  03/17/2023       61
# 5                  Cocaine Bear  02/23/2023       66
# 6          John Wick: Chapter 4  03/23/2023       80
# 7  Puss in Boots: The Last Wish  12/26/2022       83
# 8               Attack on Titan  09/30/2022       59
# 9                      The Park   03/02/2023      58
#
#                                               Genre  \
# 0                                     Drama, Action
# 1                Science Fiction, Adventure, Action
# 2     Animation, Adventure, Family, Fantasy, Comedy
# 3     Animation, Comedy, Family, Adventure, Fantasy
# 4                                            Action
# 5                           Thriller, Comedy, Crime
# 6                           Action, Thriller, Crime
# 7     Animation, Family, Fantasy, Adventure, Comedy
# 8                           Action, Science Fiction
# 9  Action, Drama, Horror, Science Fiction, Thriller
#
#                                             Overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
# 5  Inspired by a true story, an oddball group of ...
# 6  With the price on his head ever increasing, Jo...
# 7  Puss in Boots discovers that his passion for a...
# 8  As viable water is depleted on Earth, a missio...
# 9  A dystopian coming-of-age movie focused on thr...
#
#                                                 Crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 5  Keri Russell, Sari, Alden Ehrenreich, Eddie, O...
# 6  Keanu Reeves, John Wick, Donnie Yen, Caine, Bi...
# 7  Antonio Banderas, Puss in Boots (voice), Salma...
# 8  Paul Bianchi, Computer (voice), Erin Coker, Al...
# 9  Chloe Guidry, Ines, Nhedrick Jabier, Bui, Carm...
#
#                      Orig_title     Status            Orig_lang     Budget_x  \
# 0                     Creed III   Released              English   75000000.0
# 1      Avatar: The Way of Water   Released              English  460000000.0
# 2   The Super Mario Bros. Movie   Released              English  100000000.0
# 3                        Momias   Released   Spanish, Castilian   12300000.0
# 4                     Supercell   Released              English   77000000.0
# 5                  Cocaine Bear   Released              English   35000000.0
# 6          John Wick: Chapter 4   Released              English  100000000.0
# 7  Puss in Boots: The Last Wish   Released              English   90000000.0
# 8               Attack on Titan   Released              English   71000000.0
# 9                      The Park   Released              English  119200000.0
#
#         Revenue Country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US
# 5  8.000000e+07      AU
# 6  3.513494e+08      AU
# 7  4.834806e+08      AU
# 8  2.549465e+08      US
# 9  4.889625e+08      US

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#                                              Names         Year  Rating  \
# 10168                                     Marshall   06/07/2020      73
# 10169                                   Nighthawks   04/04/1981      64
# 10170                                The Love Guru   07/10/2008      42
# 10171  The Seven Deadly Sins: Prisoners of the Sky  08/18/2018       76
# 10172                            The Lady Vanishes   10/07/1938      75
# 10173                           20th Century Women  12/28/2016       73
# 10174      Delta Force 2: The Colombian Connection  08/24/1990       54
# 10175                             The Russia House  12/21/1990       61
# 10176             Darkman II: The Return of Durant   07/11/1995      55
# 10177           The Swan Princess: A Royal Wedding  07/20/2020       70
#
#                                                    Genre  \
# 10168                                              Drama
# 10169                            Action, Crime, Thriller
# 10170                                    Comedy, Romance
# 10171              Action, Adventure, Fantasy, Animation
# 10172                          Mystery, Thriller, Comedy
# 10173                                              Drama
# 10174                                             Action
# 10175                           Drama, Thriller, Romance
# 10176  Action, Adventure, Science Fiction, Thriller, ...
# 10177                         Animation, Family, Fantasy
#
#                                                 Overview  \
# 10168  Thurgood Marshall, the first African-American ...
# 10169  An international terrorist has New York in a g...
# 10170  Born in America and raised in an Indian ashram...
# 10171  Traveling in search of the rare ingredient, “s...
# 10172  On a train headed for England a group of trave...
# 10173  In 1979 Santa Barbara, California, Dorothea Fi...
# 10174  When DEA agents are taken captive by a ruthles...
# 10175  Barley Scott Blair, a Lisbon-based editor of R...
# 10176  Darkman and Durant return and they hate each o...
# 10177  Princess Odette and Prince Derek are going to ...
#
#                                                     Crew  \
# 10168  Chadwick Boseman, Thurgood Marshall, Josh Gad,...
# 10169  Sylvester Stallone, Det. Sgt. Deke DaSilva, Ru...
# 10170  Mike Myers, Guru Pitka, Jessica Alba, Jane Bul...
# 10171  Yuki Kaji, Meliodas (voice), Sora Amamiya, Eli...
# 10172  Margaret Lockwood, Iris Matilda Henderson, Mic...
# 10173  Annette Bening, Dorothea Fields, Lucas Jade Zu...
# 10174  Chuck Norris, Col. Scott McCoy, Billy Drago, R...
# 10175  Sean Connery, Bartholomew 'Barley' Scott Blair...
# 10176  Larry Drake, Robert G. Durant, Arnold Vosloo, ...
# 10177  Nina Herzog, Princess Odette (voice), Yuri Low...
#
#                                     Orig_title     Status  Orig_lang  \
# 10168                                 Marshall   Released    English
# 10169                               Nighthawks   Released    English
# 10170                            The Love Guru   Released    English
# 10171                        劇場版 七つの大罪 天空の囚われ人   Released   Japanese
# 10172                        The Lady Vanishes   Released    English
# 10173                       20th Century Women   Released    English
# 10174  Delta Force 2: The Colombian Connection   Released    English
# 10175                         The Russia House   Released    English
# 10176         Darkman II: The Return of Durant   Released    English
# 10177       The Swan Princess: A Royal Wedding   Released    English
#
#           Budget_x      Revenue Country
# 10168   12000000.0   10116816.0      AU
# 10169    5000000.0   19600000.0      US
# 10170   62000000.0   40159017.0      AU
# 10171   62600000.0  706002070.8      JP
# 10172  132000000.0  563756432.6      GB
# 10173    7000000.0    9353729.0      US
# 10174    9145817.8    6698361.0      US
# 10175   21800000.0   22997992.0      US
# 10176  116000000.0  475661306.0      US
# 10177   92400000.0  539401838.6      GB

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (10178, 12)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 10178
# Number of Columns 12

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Names       10178 non-null  object
#  1   Year        10178 non-null  object
#  2   Rating      10178 non-null  int64
#  3   Genre       10093 non-null  object
#  4   Overview    10178 non-null  object
#  5   Crew        10122 non-null  object
#  6   Orig_title  10178 non-null  object
#  7   Status      10178 non-null  object
#  8   Orig_lang   10178 non-null  object
#  9   Budget_x    10178 non-null  float64
#  10  Revenue     10178 non-null  float64
#  11  Country     10178 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 954.3+ KB

# %% [markdown]
# # 5. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Names          0
# Year           0
# Rating         0
# Genre         85
# Overview       0
# Crew          56
# Orig_title     0
# Status         0
# Orig_lang      0
# Budget_x       0
# Revenue        0
# Country        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 6. Drop All The Missing Values

# %%
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 7. Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %% [markdown]
# # 8. Get Overall Statistics About The DataFrame

# %%
data.describe()
# Out:
#             Rating      Budget_x       Revenue
# count  10052.00000  1.005200e+04  1.005200e+04
# mean      63.82700  6.412528e+07  2.512049e+08
# std       12.78271  5.665852e+07  2.765495e+08
# min        0.00000  1.000000e+00  0.000000e+00
# 25%       59.00000  1.439763e+07  2.768781e+07
# 50%       65.00000  5.000000e+07  1.493288e+08
# 75%       71.00000  1.040000e+08  4.161578e+08
# max      100.00000  4.600000e+08  2.923706e+09

# %% [markdown]
# # 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
data[data['Runtime (Minutes)']>=180]['Title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Runtime (Minutes)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\VS Code\python\IoT_project\data-analysis-imdb-movie-dataset.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/VS%20Code/python/IoT_project/data-analysis-imdb-movie-dataset.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> data[data['Runtime (Minutes)']>=180]['Title']
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Runtime (Minutes)'

# %% [markdown]
# # 10. In Which Year There Was The Highest Voting?

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %% [markdown]
# # 11. In Which Year There Was The Highest Revenue?

# %%
sns.barplot(x='Year',y='Revenue',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# # 12. Find The Average Rating For Each Director

# %%
data.groupby('Names')['Rating'].mean().sort_values(ascending=False)
# Out:
# Names
# Simulant                        100.0
# Housekeeper                     100.0
# Orgasm Lecture 2                100.0
# Furin, hentai, monmon chômon    100.0
# Pretty Young Sister 4           100.0
#                                 ...
# Kartu Pos Wini                    0.0
# Kandahar                          0.0
# Kahit Maputi na ang Buhok Ko      0.0
# Johnny & Clyde                    0.0
# 솔라 플라워                            0.0
# Name: Rating, Length: 9538, dtype: float64

# %% [markdown]
# # 13. Display Top 10 Lengthy Movies Title

# %%
le =data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')

# %%
sns.barplot(le['Runtime (Minutes)'],y=le.index)
plt.title('Top 5 Lengtly Movies')
plt.show()

# %% [markdown]
# # 14. Display Number of Movies Per Year

# %%
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")
# Out:
# Text(0.5, 1.0, 'Number of Movies Per Year')

# %% [markdown]
# # 15. Find Most Popular Movie Title (Higest Revenue)

# %%
data.columns
# Out:
# Index(['Names', 'Year', 'Rating', 'Genre', 'Overview', 'Crew', 'Orig_title',
#        'Status', 'Orig_lang', 'Budget_x', 'Revenue', 'Country'],
#       dtype='object')

# %%
data[data['Revenue'].max() == data['Revenue']]['Names']
# Out:
# 68    Avatar
# Name: Names, dtype: object

# %% [markdown]
# # 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
top_10=data.nlargest(10,'Rating')[['Names','Rating','Revenue']].set_index('Names')

# %%
top_10
# Out:
#                                         Rating       Revenue
# Names
# Orgasm Lecture 2                           100  1.569324e+09
# El asistente                               100  1.569324e+09
# Female Boss Hooker                         100  1.569324e+09
# Pretty Young Sister 4                      100  1.569324e+09
# The Chosen: Season 3  - Episodes 1 & 2     100  1.569324e+09
# Furin, hentai, monmon chômon               100  1.569324e+09
# Housekeeper                                100  1.569324e+09
# Simulant                                   100  1.569324e+09
# Rebound                                     98  1.749201e+07
# Directing Annabelle: Creation               93  1.644265e+09

# %%
sns.barplot(x='Rating',y=top_10.index,data=top_10,hue='Revenue',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1))

# %% [markdown]
# # 17. Display Top 10 Highest Revenue Movie Titles

# %%
data.columns
# Out:
# Index(['Names', 'Year', 'Rating', 'Genre', 'Overview', 'Crew', 'Orig_title',
#        'Status', 'Orig_lang', 'Budget_x', 'Revenue', 'Country'],
#       dtype='object')

# %%
data.sort_values(by='Revenue',ascending=False).head(10)
# Out:
#                                        Names         Year  Rating  \
# 68                                    Avatar  12/17/2009       76
# 230                        Avengers: Endgame  04/24/2019       83
# 1                   Avatar: The Way of Water  12/15/2022       78
# 309                                  Titanic  12/18/1997       79
# 6670                                 Titanic   04/11/1953      66
# 4483    Louis Tomlinson: All of Those Voices  03/22/2023       91
# 943             Star Wars: The Force Awakens  12/17/2015       73
# 104                   Avengers: Infinity War  04/25/2018       83
# 76                   Spider-Man: No Way Home  12/16/2021       80
# 2156  BTS: Permission to Dance on Stage - LA   09/08/2022      92
#
#                                             Genre  \
# 68    Action, Adventure, Fantasy, Science Fiction
# 230            Adventure, Science Fiction, Action
# 1              Science Fiction, Adventure, Action
# 309                                Drama, Romance
# 6670                               Drama, Romance
# 4483                           Documentary, Music
# 943   Adventure, Action, Science Fiction, Fantasy
# 104            Adventure, Action, Science Fiction
# 76             Action, Adventure, Science Fiction
# 2156                           Music, Documentary
#
#                                                Overview  \
# 68    In the 22nd century, a paraplegic Marine is di...
# 230   After the devastating events of Avengers: Infi...
# 1     Set more than a decade after the events of the...
# 309   101-year-old Rose DeWitt Bukater tells the sto...
# 6670  Unhappily married, Julia Sturges decides to go...
# 4483  Ditching the typical glossy sheen of celebrity...
# 943   Thirty years after defeating the Galactic Empi...
# 104   As the Avengers and their allies have continue...
# 76    Peter Parker is unmasked and no longer able to...
# 2156  Purple colors the city of Los Angeles, as BTS ...
#
#                                                    Crew  \
# 68    Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 230   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 1     Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 309   Leonardo DiCaprio, Jack Dawson, Kate Winslet, ...
# 6670  Clifton Webb, Richard Ward Sturges, Barbara St...
# 4483  Louis Tomlinson, Self, Oliver Wright, Louis’ P...
# 943   Harrison Ford, Han Solo, Mark Hamill, Luke Sky...
# 104   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 76    Tom Holland, Peter Parker / Spider-Man, Zenday...
# 2156  Kim Nam-joon, Self, Kim Seok-jin, Self, Min Yo...
#
#                                  Orig_title     Status Orig_lang     Budget_x  \
# 68                                   Avatar   Released   English  237000000.0
# 230                       Avengers: Endgame   Released   English  400000000.0
# 1                  Avatar: The Way of Water   Released   English  460000000.0
# 309                                 Titanic   Released   English  200000000.0
# 6670                                Titanic   Released   English  200000000.0
# 4483   Louis Tomlinson: All of Those Voices   Released   English  178800000.0
# 943            Star Wars: The Force Awakens   Released   English  245000000.0
# 104                  Avengers: Infinity War   Released   English  300000000.0
# 76                  Spider-Man: No Way Home   Released   English  200000000.0
# 2156   BTS: PERMISSION TO DANCE 온 스테이지 – LA   Released    Korean  215600000.0
#
#            Revenue Country
# 68    2.923706e+09      AU
# 230   2.794732e+09      AU
# 1     2.316795e+09      AU
# 309   2.222986e+09      AU
# 6670  2.222986e+09      US
# 4483  2.081794e+09      GB
# 943   2.068224e+09      AU
# 104   2.048360e+09      AU
# 76    1.910048e+09      AU
# 2156  1.748017e+09      KR

# %%
top_10 = data.nlargest(10,'Revenue (Millions)')[['Title','Director','Revenue (Millions)']].set_index('Title')

# %%
top_10
# Out:
#                                                      Director  \
# Title
# Star Wars: Episode VII - The Force Awakens        J.J. Abrams
# Avatar                                          James Cameron
# Jurassic World                                Colin Trevorrow
# The Avengers                                      Joss Whedon
# The Dark Knight                             Christopher Nolan
# Rogue One                                      Gareth Edwards
# Finding Dory                                   Andrew Stanton
# Avengers: Age of Ultron                           Joss Whedon
# The Dark Knight Rises                       Christopher Nolan
# The Hunger Games: Catching Fire              Francis Lawrence
#
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
sns.barplot(top_10['Revenue (Millions)'],top_10.index)
plt.title("Display Top 10 Highest Revenue Movie Titles")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.barplot(top_10['Revenue (Millions)'],top_10.index)
#       2 plt.title("Display Top 10 Highest Revenue Movie Titles")
#       3 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# # 18.  Find Average Rating of Movies Year-wise

# %%
data.columns

# %%
data1=data.groupby('Year')['Year','Rating'].mean().\
sort_values(by='Rating',ascending=False).set_index('Year')

# %%
data1

# %%
plt.figure(figsize=(10,5))
sns.barplot(data1.index,data1['Rating'])
plt.show()

# %% [markdown]
# # 19. Does Rating Affect The Revenue?

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)

# %% [markdown]
# # Answer : Yes

# %% [markdown]
# # 20. Classify Movies Based on Ratings [Good,Better and Best]

# %%
data.columns

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head(1)

# %% [markdown]
# # 21. Count Number of Action Movies

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))

# %%
data['temp']=list1

# %%
genre=input("Enter Genre you want to count : ").title()
count=0
for value in data['temp']:
    if genre in value:
        count=count+1
print("Total Count is",count)

# %% [markdown]
# # OR

# %%
len(data[data['Genre'].str.contains('action',case=False)])
